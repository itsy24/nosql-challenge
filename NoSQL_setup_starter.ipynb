# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Part 1: Database and Jupyter Notebook Set Up

# %% [markdown]
# Import the data provided in the `establishments.json` file from your Terminal. Name the database `uk_food` and the collection `establishments`.
#
# Import the dataset with:
# mongoimport --type json -d uk_food -c establishments --drop --jsonArray establishments.json

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint

#import dataset with:
# mongoimport --type json -d uk_food -c establishments --drop --jsonArray establishments.json

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# confirm that our new database was created
print(mongo.list_database_names())
# Out:
# ['admin', 'class_db', 'config', 'epa', 'fruits_db', 'gardendb', 'local', 'petsitly_marketing', 'recordsdb', 'travel_db', 'uk_food']

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our new database
print(db.list_collection_names())
# Out:
# ['establishments']

# %%
# assign the collection to a variable
establishments = db['establishments']

# %%
# review a document in the establishments collection
pprint(establishments.find_one())
# Out:
# {'AddressLine1': '1 The Droveway',
#  'AddressLine2': 'St Margarets Bay',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'FirstLight Bar & Café',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4587.64041272672,
#  'FHRSID': 1290215,
#  'LocalAuthorityBusinessID': 'PI/000083029',
#  'LocalAuthorityCode': '182',
#  'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#  'LocalAuthorityName': 'Dover',
#  'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT15 6DH',
#  'RatingDate': '2020-11-09T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': '5',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6444c50c4e68f4e55d0228a6'),
#  'geocode': {'latitude': '51.150625', 'longitude': '1.378231'},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1290215',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}}

# %% [markdown]
# ## Part 2: Update the Database

# %% [markdown]
# 1. An exciting new halal restaurant just opened in Greenwich, but hasn't been rated yet. The magazine has asked you to include it in your analysis. Add the following restaurant "Penang Flavours" to the database.

# %%
# Create a dictionary for the new restaurant data
new_restaurant = {"BusinessName":"Penang Flavours",
    "BusinessType":"Restaurant/Cafe/Canteen",
    "BusinessTypeID":"",
    "AddressLine1":"Penang Flavours",
    "AddressLine2":"146A Plumstead Rd",
    "AddressLine3":"London",
    "AddressLine4":"",
    "PostCode":"SE18 7DY",
    "Phone":"",
    "LocalAuthorityCode":"511",
    "LocalAuthorityName":"Greenwich",
    "LocalAuthorityWebSite":"http://www.royalgreenwich.gov.uk",
    "LocalAuthorityEmailAddress":"health@royalgreenwich.gov.uk",
    "scores":{
        "Hygiene":"",
        "Structural":"",
        "ConfidenceInManagement":""},
    "SchemeType":"FHRS",
    "geocode":{"longitude":"0.08384000",
               "latitude":"51.49014200"},
    "RightToReply":"",
    "Distance":4623.9723280747176,
    "NewRatingPending":True}

# %%
# Insert the new restaurant into the collection
establishments.insert_one(new_restaurant)

# %%
# Check that the new restaurant was inserted
establishments.find_one({'BusinessName': 'Penang Flavours'})
# Out:
# {'_id': ObjectId('6444c52720249a651f1e8bc4'),
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '',
#  'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'PostCode': 'SE18 7DY',
#  'Phone': '',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'scores': {'Hygiene': '', 'Structural': '', 'ConfidenceInManagement': ''},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': '0.08384000', 'latitude': '51.49014200'},
#  'RightToReply': '',
#  'Distance': 4623.972328074718,
#  'NewRatingPending': True}

# %% [markdown]
# 2. Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the `BusinessTypeID` and `BusinessType` fields.

# %%
# Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the BusinessTypeID and BusinessType fields
query_business_type = {'BusinessType': 'Restaurant/Cafe/Canteen'}
fields = {'BusinessTypeID':1,'BusinessType':1}

pprint(establishments.find_one(query_business_type))
# Out:
# {'AddressLine1': '1 The Droveway',
#  'AddressLine2': 'St Margarets Bay',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'FirstLight Bar & Café',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4587.64041272672,
#  'FHRSID': 1290215,
#  'LocalAuthorityBusinessID': 'PI/000083029',
#  'LocalAuthorityCode': '182',
#  'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#  'LocalAuthorityName': 'Dover',
#  'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT15 6DH',
#  'RatingDate': '2020-11-09T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': '5',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6444c50c4e68f4e55d0228a6'),
#  'geocode': {'latitude': '51.150625', 'longitude': '1.378231'},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1290215',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}}

# %% [markdown]
# 3. Update the new restaurant with the `BusinessTypeID` you found.

# %%
# Update the new restaurant with the correct BusinessTypeID
query_business_id = {'BusinessName': 'Penang Flavours','BusinessTypeID': ''}
update_businessID = {'$set': {'BusinessTypeID':1} }

establishments.update_one(query_business_id, update_businessID)

# %%
# Confirm that the new restaurant was updated
establishments.find_one({'BusinessName': 'Penang Flavours'})
# Out:
# {'_id': ObjectId('6444c52720249a651f1e8bc4'),
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'PostCode': 'SE18 7DY',
#  'Phone': '',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'scores': {'Hygiene': '', 'Structural': '', 'ConfidenceInManagement': ''},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': '0.08384000', 'latitude': '51.49014200'},
#  'RightToReply': '',
#  'Distance': 4623.972328074718,
#  'NewRatingPending': True}

# %% [markdown]
# 4. The magazine is not interested in any establishments in Dover, so check how many documents contain the Dover Local Authority. Then, remove any establishments within the Dover Local Authority from the database, and check the number of documents to ensure they were deleted.

# %%
# Find how many documents have LocalAuthorityName as "Dover"
query_dover = {'LocalAuthorityName': 'Dover'}
print(establishments.count_documents(query_dover))
# Out:
# 994

# %%
# Delete all documents where LocalAuthorityName is "Dover"
establishments.delete_many(query_dover)
updated_list = establishments.find(query_dover)

# %%
# Check if any remaining documents include Dover
query_dover = {'LocalAuthorityName': 'Dover'}
print(establishments.count_documents(query_dover))
# Out:
# 0

# %%
# Check that other documents remain with 'find_one'
establishments.find_one()
# Out:
# {'_id': ObjectId('6444c50c4e68f4e55d022b8a'),
#  'FHRSID': 647177,
#  'ChangesByServerID': 0,
#  'LocalAuthorityBusinessID': 'PI/000041489',
#  'BusinessName': 'Wear Bay Bowls Club',
#  'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  'AddressLine1': 'Wear Bay Road',
#  'AddressLine2': 'Folkestone',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'PostCode': 'CT19 6PY',
#  'Phone': '',
#  'RatingValue': '4',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingDate': '2014-03-31T00:00:00',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 10},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': '1.196408', 'latitude': '51.086058'},
#  'RightToReply': '',
#  'Distance': 4591.821311183521,
#  'NewRatingPending': False,
#  'meta': {'dataSource': None,
#   'extractDate': '0001-01-01T00:00:00',
#   'itemCount': 0,
#   'returncode': None,
#   'totalCount': 0,
#   'totalPages': 0,
#   'pageSize': 0,
#   'pageNumber': 0},
#  'links': [{'rel': 'self',
#    'href': 'https://api.ratings.food.gov.uk/establishments/647177'}]}

# %% [markdown]
# 5. Some of the number values are stored as strings, when they should be stored as numbers.

# %% [markdown]
# Use `update_many` to convert `latitude` and `longitude` to decimal numbers.

# %%
# Change the data type from String to Decimal for longitude and latitude
establishments.update_many({}, [ {'$set':{'geocode.longitude': {'$toDouble': '$geocode.longitude'}, 
                                         'geocode.latitude': {'$toDouble': '$geocode.latitude'}}} ])

# %% [markdown]
# Use `update_many` to convert `RatingValue` to integer numbers.

# %%
# Set non 1-5 Rating Values to Null
non_ratings = ["AwaitingInspection", "Awaiting Inspection", "AwaitingPublication", "Pass", "Exempt"]
establishments.update_many({"RatingValue": {"$in": non_ratings}}, [ {'$set':{ "RatingValue" : None}} ])

# %%
# Change the data type from String to Integer for RatingValue
establishments.update_many({}, [ {'$set':{'RatingValue': {'$toInt': '$RatingValue'}}} ])

# %%
# Check that the coordinates and rating value are now numbers
check_updates = establishments.find({},['RatingValue','geocode.longitude','geocode.latitude' ])
[pprint(update) for update in check_updates]
# Out:
# {'RatingValue': 4,
#  '_id': ObjectId('6444c50c4e68f4e55d022b8a'),
#  'geocode': {'latitude': 51.086058, 'longitude': 1.196408}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022b8c'),
#  'geocode': {'latitude': 51.083812, 'longitude': 1.195625}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022b8d'),
#  'geocode': {'latitude': 51.085797, 'longitude': 1.194762}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022b90'),
#  'geocode': {'latitude': 51.08084, 'longitude': 1.188537}}
# {'RatingValue': 4,
#  '_id': ObjectId('6444c50c4e68f4e55d022b91'),
#  'geocode': {'latitude': 51.08084, 'longitude': 1.188537}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022b92'),
#  'geocode': {'latitude': 51.08084, 'longitude': 1.188537}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022b93'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022b94'),
#  'geocode': {'latitude': 51.08084, 'longitude': 1.188537}}
# {'RatingValue': 4,
#  '_id': ObjectId('6444c50c4e68f4e55d022b95'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022b96'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022b97'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022b9a'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022b9b'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022b9c'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022b9d'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022b9e'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022b9f'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'RatingValue': 3,
#  '_id': ObjectId('6444c50c4e68f4e55d022ba0'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'RatingValue': 3,
#  '_id': ObjectId('6444c50c4e68f4e55d022ba1'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'RatingValue': 4,
#  '_id': ObjectId('6444c50c4e68f4e55d022ba2'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022ba3'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022ba4'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022ba5'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022ba6'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022ba7'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022ba8'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022ba9'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'RatingValue': 2,
#  '_id': ObjectId('6444c50c4e68f4e55d022baa'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'RatingValue': 4,
#  '_id': ObjectId('6444c50c4e68f4e55d022bab'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022bac'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'RatingValue': 2,
#  '_id': ObjectId('6444c50c4e68f4e55d022bad'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022bae'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'RatingValue': 4,
#  '_id': ObjectId('6444c50c4e68f4e55d022baf'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022bb0'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022bb1'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'RatingValue': None,
#  '_id': ObjectId('6444c50c4e68f4e55d022bb2'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022bb3'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'RatingValue': 4,
#  '_id': ObjectId('6444c50c4e68f4e55d022bb4'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'RatingValue': 3,
#  '_id': ObjectId('6444c50c4e68f4e55d022bb5'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022bb6'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022bb7'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'RatingValue': None,
#  '_id': ObjectId('6444c50c4e68f4e55d022bb8'),
#  'geocode': {'latitude': 51.0805695006979, 'longitude': 1.18794649942731}}
# {'RatingValue': 2,
#  '_id': ObjectId('6444c50c4e68f4e55d022bba'),
#  'geocode': {'latitude': 51.078449, 'longitude': 1.18516}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022bbb'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022bbc'),
#  'geocode': {'latitude': 51.095015, 'longitude': 1.202055}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022bbd'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022bbe'),
#  'geocode': {'latitude': 51.080673, 'longitude': 1.187083}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022bbf'),
#  'geocode': {'latitude': 51.080446, 'longitude': 1.186825}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022bc0'),
#  'geocode': {'latitude': 51.079985650005, 'longitude': 1.18628335007084}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022bc2'),
#  'geocode': {'latitude': 51.080284, 'longitude': 1.186485}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022bc3'),
#  'geocode': {'latitude': 51.087887, 'longitude': 1.194306}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022bc4'),
#  'geocode': {'latitude': 51.079613, 'longitude': 1.185368}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022bc5'),
#  'geocode': {'latitude': 51.079613, 'longitude': 1.185368}}
# {'RatingValue': 3,
#  '_id': ObjectId('6444c50c4e68f4e55d022bc6'),
#  'geocode': {'latitude': 51.077971, 'longitude': 1.183585}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022bc7'),
#  'geocode': {'latitude': 51.083232, 'longitude': 1.188902}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022bc9'),
#  'geocode': {'latitude': 51.080838, 'longitude': 1.186309}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022bca'),
#  'geocode': {'latitude': 51.081735, 'longitude': 1.187056}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022bcb'),
#  'geocode': {'latitude': 51.081546, 'longitude': 1.186715}}
# {'RatingValue': 2,
#  '_id': ObjectId('6444c50c4e68f4e55d022bcc'),
#  'geocode': {'latitude': 51.07915, 'longitude': 1.184194}}
# {'RatingValue': 3,
#  '_id': ObjectId('6444c50c4e68f4e55d022bcd'),
#  'geocode': {'latitude': 51.07915, 'longitude': 1.184194}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022bcf'),
#  'geocode': {'latitude': 51.086262, 'longitude': 1.190896}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022bd0'),
#  'geocode': {'latitude': 51.0803, 'longitude': 1.184916}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022bd2'),
#  'geocode': {'latitude': 51.0877821, 'longitude': 1.1920251}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022bd3'),
#  'geocode': {'latitude': 51.0818061828613, 'longitude': 1.18601894378662}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022bd4'),
#  'geocode': {'latitude': 51.080284, 'longitude': 1.186485}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022bd8'),
#  'geocode': {'latitude': 51.0804824829102, 'longitude': 1.18421399593353}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022bd9'),
#  'geocode': {'latitude': 51.0804748535156, 'longitude': 1.18425798416138}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022bda'),
#  'geocode': {'latitude': 51.0793, 'longitude': 1.182962}}
# {'RatingValue': 4,
#  '_id': ObjectId('6444c50c4e68f4e55d022bdb'),
#  'geocode': {'latitude': 51.079301, 'longitude': 1.182962}}
# {'RatingValue': 3,
#  '_id': ObjectId('6444c50c4e68f4e55d022bdc'),
#  'geocode': {'latitude': 51.080956, 'longitude': 1.18429}}
# {'RatingValue': 4,
#  '_id': ObjectId('6444c50c4e68f4e55d022bdd'),
#  'geocode': {'latitude': 51.097794, 'longitude': 1.201433}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022bde'),
#  'geocode': {'latitude': 51.080224, 'longitude': 1.186067}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022bdf'),
#  'geocode': {'latitude': 51.080804, 'longitude': 1.183893}}
# {'RatingValue': None,
#  '_id': ObjectId('6444c50c4e68f4e55d022be0'),
#  'geocode': {'latitude': 51.0917365039471, 'longitude': 1.19522100055125}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022be1'),
#  'geocode': {'latitude': 51.079905, 'longitude': 1.182875}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022be2'),
#  'geocode': {'latitude': 51.080339, 'longitude': 1.182805}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022be3'),
#  'geocode': {'latitude': 51.080339, 'longitude': 1.182805}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022be4'),
#  'geocode': {'latitude': 51.0810258, 'longitude': 1.1835476}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022be5'),
#  'geocode': {'latitude': 51.08034, 'longitude': 1.182805}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022be6'),
#  'geocode': {'latitude': 51.080956, 'longitude': 1.18429}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022be7'),
#  'geocode': {'latitude': 51.08034, 'longitude': 1.182805}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022be8'),
#  'geocode': {'latitude': 51.08034, 'longitude': 1.182805}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022be9'),
#  'geocode': {'latitude': 51.0804824829102, 'longitude': 1.18421399593353}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022bea'),
#  'geocode': {'latitude': 51.08034, 'longitude': 1.182805}}
# {'RatingValue': 4,
#  '_id': ObjectId('6444c50c4e68f4e55d022beb'),
#  'geocode': {'latitude': 51.080956, 'longitude': 1.18429}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022bed'),
#  'geocode': {'latitude': 51.0802956, 'longitude': 1.1823865}}
# {'RatingValue': 4,
#  '_id': ObjectId('6444c50c4e68f4e55d022bee'),
#  'geocode': {'latitude': 51.079889, 'longitude': 1.181832}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022bef'),
#  'geocode': {'latitude': 51.079532623291, 'longitude': 1.1813759803772}}
# {'RatingValue': 3,
#  '_id': ObjectId('6444c50c4e68f4e55d022bf0'),
#  'geocode': {'latitude': 51.0803409, 'longitude': 1.1822069}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022bf1'),
#  'geocode': {'latitude': 51.079542, 'longitude': 1.181365}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022bf2'),
#  'geocode': {'latitude': 51.079542, 'longitude': 1.181365}}
# {'RatingValue': 4,
#  '_id': ObjectId('6444c50c4e68f4e55d022bf3'),
#  'geocode': {'latitude': 51.079542, 'longitude': 1.181365}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022bf4'),
#  'geocode': {'latitude': 51.0798931, 'longitude': 1.1817077}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022bf5'),
#  'geocode': {'latitude': 51.080412, 'longitude': 1.182125}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022bf6'),
#  'geocode': {'latitude': 51.080412, 'longitude': 1.182125}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022bf7'),
#  'geocode': {'latitude': 51.079799, 'longitude': 1.181482}}
# {'RatingValue': None,
#  '_id': ObjectId('6444c50c4e68f4e55d022bf8'),
#  'geocode': {'latitude': 51.0798, 'longitude': 1.181483}}
# {'RatingValue': 3,
#  '_id': ObjectId('6444c50c4e68f4e55d022bf9'),
#  'geocode': {'latitude': 51.078209, 'longitude': 1.179446}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022bfa'),
#  'geocode': {'latitude': 51.0800235, 'longitude': 1.1813097}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022bfb'),
#  'geocode': {'latitude': 51.0802346, 'longitude': 1.1814856}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022bfc'),
#  'geocode': {'latitude': 51.0797886, 'longitude': 1.1810166}}
# {'RatingValue': 4,
#  '_id': ObjectId('6444c50c4e68f4e55d022bfd'),
#  'geocode': {'latitude': 51.0809478759766, 'longitude': 1.18431901931763}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022bfe'),
#  'geocode': {'latitude': 51.089491, 'longitude': 1.190904}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022bff'),
#  'geocode': {'latitude': 51.089491, 'longitude': 1.190904}}
# {'RatingValue': 3,
#  '_id': ObjectId('6444c50c4e68f4e55d022c00'),
#  'geocode': {'latitude': 51.0806732177734, 'longitude': 1.18172800540924}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022c01'),
#  'geocode': {'latitude': 51.080675, 'longitude': 1.181728}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022c02'),
#  'geocode': {'latitude': 51.080675, 'longitude': 1.181728}}
# {'RatingValue': 3,
#  '_id': ObjectId('6444c50c4e68f4e55d022c03'),
#  'geocode': {'latitude': 51.080675, 'longitude': 1.181728}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022c04'),
#  'geocode': {'latitude': 51.080675, 'longitude': 1.181728}}
# {'RatingValue': 4,
#  '_id': ObjectId('6444c50c4e68f4e55d022c05'),
#  'geocode': {'latitude': 51.080675, 'longitude': 1.181728}}
# {'RatingValue': None,
#  '_id': ObjectId('6444c50c4e68f4e55d022c06'),
#  'geocode': {'latitude': 51.080675, 'longitude': 1.181728}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022c07'),
#  'geocode': {'latitude': 51.0806941, 'longitude': 1.1817227}}
# {'RatingValue': 3,
#  '_id': ObjectId('6444c50c4e68f4e55d022c08'),
#  'geocode': {'latitude': 51.082322, 'longitude': 1.183327}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022c09'),
#  'geocode': {'latitude': 51.0793698, 'longitude': 1.1802781}}
# {'RatingValue': 4,
#  '_id': ObjectId('6444c50c4e68f4e55d022c0a'),
#  'geocode': {'latitude': 51.080805, 'longitude': 1.183894}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022c0b'),
#  'geocode': {'latitude': 51.08164, 'longitude': 1.182609}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022c0c'),
#  'geocode': {'latitude': 51.080956, 'longitude': 1.18429}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022c0d'),
#  'geocode': {'latitude': 51.08164, 'longitude': 1.182609}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022c0e'),
#  'geocode': {'latitude': 51.083976, 'longitude': 1.185011}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022c0f'),
#  'geocode': {'latitude': 51.07954, 'longitude': 1.180437}}
# {'RatingValue': 3,
#  '_id': ObjectId('6444c50c4e68f4e55d022c10'),
#  'geocode': {'latitude': 51.07954, 'longitude': 1.180437}}
# {'RatingValue': 4,
#  '_id': ObjectId('6444c50c4e68f4e55d022c11'),
#  'geocode': {'latitude': 51.07954, 'longitude': 1.180437}}
# {'RatingValue': None,
#  '_id': ObjectId('6444c50c4e68f4e55d022c12'),
#  'geocode': {'latitude': 51.07954, 'longitude': 1.180437}}
# {'RatingValue': 4,
#  '_id': ObjectId('6444c50c4e68f4e55d022c13'),
#  'geocode': {'latitude': 51.0816612, 'longitude': 1.1826116}}
# {'RatingValue': 4,
#  '_id': ObjectId('6444c50c4e68f4e55d022c14'),
#  'geocode': {'latitude': 51.08472, 'longitude': 1.185748}}
# {'RatingValue': 2,
#  '_id': ObjectId('6444c50c4e68f4e55d022c15'),
#  'geocode': {'latitude': 51.084721, 'longitude': 1.185748}}
# {'RatingValue': 4,
#  '_id': ObjectId('6444c50c4e68f4e55d022c16'),
#  'geocode': {'latitude': 51.0818634033203, 'longitude': 1.18279695510864}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022c17'),
#  'geocode': {'latitude': 51.080181, 'longitude': 1.181023}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022c18'),
#  'geocode': {'latitude': 51.080417, 'longitude': 1.181282}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022c19'),
#  'geocode': {'latitude': 51.08187, 'longitude': 1.182753}}
# {'RatingValue': 4,
#  '_id': ObjectId('6444c50c4e68f4e55d022c1a'),
#  'geocode': {'latitude': 51.08187, 'longitude': 1.182753}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022c1b'),
#  'geocode': {'latitude': 51.08187, 'longitude': 1.182753}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022c1c'),
#  'geocode': {'latitude': 51.081494, 'longitude': 1.182356}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022c1d'),
#  'geocode': {'latitude': 51.078296, 'longitude': 1.178909}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022c1e'),
#  'geocode': {'latitude': 51.078296, 'longitude': 1.178909}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022c1f'),
#  'geocode': {'latitude': 51.078296, 'longitude': 1.178909}}
# {'RatingValue': 4,
#  '_id': ObjectId('6444c50c4e68f4e55d022c20'),
#  'geocode': {'latitude': 51.078296, 'longitude': 1.178909}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022c21'),
#  'geocode': {'latitude': 51.085454, 'longitude': 1.186241}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022c22'),
#  'geocode': {'latitude': 51.086189, 'longitude': 1.186977}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022c23'),
#  'geocode': {'latitude': 51.086189, 'longitude': 1.186977}}
# {'RatingValue': 3,
#  '_id': ObjectId('6444c50c4e68f4e55d022c24'),
#  'geocode': {'latitude': 51.0785865783691, 'longitude': 1.17911505699158}}
# {'RatingValue': None,
#  '_id': ObjectId('6444c50c4e68f4e55d022c25'),
#  'geocode': {'latitude': 51.078587, 'longitude': 1.179115}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022c26'),
#  'geocode': {'latitude': 51.0780695, 'longitude': 1.1785097}}
# {'RatingValue': None,
#  '_id': ObjectId('6444c50c4e68f4e55d022c27'),
#  'geocode': {'latitude': 51.0798709, 'longitude': 1.1803396}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022c28'),
#  'geocode': {'latitude': 51.0802287, 'longitude': 1.1806797}}
# {'RatingValue': 4,
#  '_id': ObjectId('6444c50c4e68f4e55d022c29'),
#  'geocode': {'latitude': 51.080417, 'longitude': 1.181282}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022c2a'),
#  'geocode': {'latitude': 51.0804176330566, 'longitude': 1.18128204345703}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022c2b'),
#  'geocode': {'latitude': 51.078117, 'longitude': 1.1784815}}
# {'RatingValue': None,
#  '_id': ObjectId('6444c50c4e68f4e55d022c2c'),
#  'geocode': {'latitude': 51.0781968, 'longitude': 1.1783613}}
# {'RatingValue': 3,
#  '_id': ObjectId('6444c50c4e68f4e55d022c2d'),
#  'geocode': {'latitude': 51.0781968, 'longitude': 1.1783613}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022c2e'),
#  'geocode': {'latitude': 51.079632, 'longitude': 1.179729}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022c2f'),
#  'geocode': {'latitude': 51.079632, 'longitude': 1.179729}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022c30'),
#  'geocode': {'latitude': 51.083569, 'longitude': 1.183784}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022c31'),
#  'geocode': {'latitude': 51.083569, 'longitude': 1.183784}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022c32'),
#  'geocode': {'latitude': 51.080315, 'longitude': 1.18039}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022c33'),
#  'geocode': {'latitude': 51.080315, 'longitude': 1.18039}}
# {'RatingValue': 4,
#  '_id': ObjectId('6444c50c4e68f4e55d022c34'),
#  'geocode': {'latitude': 51.078131, 'longitude': 1.178027}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022c35'),
#  'geocode': {'latitude': 51.0818613, 'longitude': 1.1818685}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022c36'),
#  'geocode': {'latitude': 51.0818613, 'longitude': 1.1818685}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022c39'),
#  'geocode': {'latitude': 51.080211, 'longitude': 1.179926}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022c3a'),
#  'geocode': {'latitude': 51.080211, 'longitude': 1.179926}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022c3b'),
#  'geocode': {'latitude': 51.080211, 'longitude': 1.179925}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022c3c'),
#  'geocode': {'latitude': 51.079481, 'longitude': 1.178961}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022c3d'),
#  'geocode': {'latitude': 51.079161, 'longitude': 1.17884}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022c3e'),
#  'geocode': {'latitude': 51.079482, 'longitude': 1.178962}}
# {'RatingValue': 1,
#  '_id': ObjectId('6444c50c4e68f4e55d022c3f'),
#  'geocode': {'latitude': 51.080217, 'longitude': 1.1799178}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022c40'),
#  'geocode': {'latitude': 51.081337, 'longitude': 1.180846}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022c41'),
#  'geocode': {'latitude': 51.0783483, 'longitude': 1.177752}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022c42'),
#  'geocode': {'latitude': 51.088735, 'longitude': 1.188295}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022c43'),
#  'geocode': {'latitude': 51.0783433, 'longitude': 1.1776046}}
# {'RatingValue': 4,
#  '_id': ObjectId('6444c50c4e68f4e55d022c44'),
#  'geocode': {'latitude': 51.081337, 'longitude': 1.180846}}
# {'RatingValue': None,
#  '_id': ObjectId('6444c50c4e68f4e55d022c45'),
#  'geocode': {'latitude': 51.081526, 'longitude': 1.181201}}
# {'RatingValue': 4,
#  '_id': ObjectId('6444c50c4e68f4e55d022c46'),
#  'geocode': {'latitude': 51.078317, 'longitude': 1.177468}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022c47'),
#  'geocode': {'latitude': 51.078317, 'longitude': 1.177468}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022c48'),
#  'geocode': {'latitude': 51.078317, 'longitude': 1.177468}}
# {'RatingValue': None,
#  '_id': ObjectId('6444c50c4e68f4e55d022c4a'),
#  'geocode': {'latitude': 51.078317, 'longitude': 1.177468}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022c4b'),
#  'geocode': {'latitude': 51.082867, 'longitude': 1.182136}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022c4c'),
#  'geocode': {'latitude': 51.088735, 'longitude': 1.188295}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022c4e'),
#  'geocode': {'latitude': 51.0806446, 'longitude': 1.1796215}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022c4f'),
#  'geocode': {'latitude': 51.087132, 'longitude': 1.186371}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022c50'),
#  'geocode': {'latitude': 51.080668, 'longitude': 1.179628}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022c51'),
#  'geocode': {'latitude': 51.082867, 'longitude': 1.182136}}
# {'RatingValue': None,
#  '_id': ObjectId('6444c50c4e68f4e55d022c52'),
#  'geocode': {'latitude': 51.0824157, 'longitude': 1.1817418}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022c53'),
#  'geocode': {'latitude': 51.079482, 'longitude': 1.178962}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022c54'),
#  'geocode': {'latitude': 51.080669, 'longitude': 1.179629}}
# {'RatingValue': 2,
#  '_id': ObjectId('6444c50c4e68f4e55d022c55'),
#  'geocode': {'latitude': 51.0804496, 'longitude': 1.1794011}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022c56'),
#  'geocode': {'latitude': 51.080669, 'longitude': 1.179629}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022c57'),
#  'geocode': {'latitude': 51.078211, 'longitude': 1.176733}}
# {'RatingValue': 3,
#  '_id': ObjectId('6444c50c4e68f4e55d022c58'),
#  'geocode': {'latitude': 51.076896, 'longitude': 1.175486}}
# {'RatingValue': 2,
#  '_id': ObjectId('6444c50c4e68f4e55d022c59'),
#  'geocode': {'latitude': 51.0808513, 'longitude': 1.1794486}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022c5a'),
#  'geocode': {'latitude': 51.083108, 'longitude': 1.181896}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022c5b'),
#  'geocode': {'latitude': 51.0782127380371, 'longitude': 1.17673301696777}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022c5c'),
#  'geocode': {'latitude': 51.0810699462891, 'longitude': 1.17957198619843}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022c5d'),
#  'geocode': {'latitude': 51.079081, 'longitude': 1.177506}}
# {'RatingValue': 4,
#  '_id': ObjectId('6444c50c4e68f4e55d022c5e'),
#  'geocode': {'latitude': 51.080624, 'longitude': 1.178969}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022c5f'),
#  'geocode': {'latitude': 51.079679, 'longitude': 1.17799}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022c60'),
#  'geocode': {'latitude': 51.079679, 'longitude': 1.17799}}
# {'RatingValue': None,
#  '_id': ObjectId('6444c50c4e68f4e55d022c61'),
#  'geocode': {'latitude': 51.079679, 'longitude': 1.17799}}
# {'RatingValue': 4,
#  '_id': ObjectId('6444c50c4e68f4e55d022c62'),
#  'geocode': {'latitude': 51.076653, 'longitude': 1.174813}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022c63'),
#  'geocode': {'latitude': 51.079679, 'longitude': 1.17799}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022c64'),
#  'geocode': {'latitude': 51.079081, 'longitude': 1.177506}}
# {'RatingValue': 3,
#  '_id': ObjectId('6444c50c4e68f4e55d022c65'),
#  'geocode': {'latitude': 51.0776252746582, 'longitude': 1.17575001716614}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022c66'),
#  'geocode': {'latitude': 51.077626, 'longitude': 1.17575}}
# {'RatingValue': 4,
#  '_id': ObjectId('6444c50c4e68f4e55d022c67'),
#  'geocode': {'latitude': 51.077626, 'longitude': 1.17575}}
# {'RatingValue': 3,
#  '_id': ObjectId('6444c50c4e68f4e55d022c68'),
#  'geocode': {'latitude': 51.077626, 'longitude': 1.17575}}
# {'RatingValue': 4,
#  '_id': ObjectId('6444c50c4e68f4e55d022c69'),
#  'geocode': {'latitude': 51.077626, 'longitude': 1.17575}}
# {'RatingValue': 3,
#  '_id': ObjectId('6444c50c4e68f4e55d022c6a'),
#  'geocode': {'latitude': 51.077626, 'longitude': 1.17575}}
# {'RatingValue': 1,
#  '_id': ObjectId('6444c50c4e68f4e55d022c6b'),
#  'geocode': {'latitude': 51.087185, 'longitude': 1.185418}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022c6c'),
#  'geocode': {'latitude': 51.0776458, 'longitude': 1.1753663}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022c6d'),
#  'geocode': {'latitude': 51.0758056640625, 'longitude': 1.17352676391602}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022c6e'),
#  'geocode': {'latitude': 51.076956, 'longitude': 1.174605}}
# {'RatingValue': 3,
#  '_id': ObjectId('6444c50c4e68f4e55d022c6f'),
#  'geocode': {'latitude': 51.076956, 'longitude': 1.174605}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022c70'),
#  'geocode': {'latitude': 51.07879, 'longitude': 1.176258}}
# {'RatingValue': 4,
#  '_id': ObjectId('6444c50c4e68f4e55d022c71'),
#  'geocode': {'latitude': 51.078033, 'longitude': 1.17535}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022c72'),
#  'geocode': {'latitude': 51.078513, 'longitude': 1.175897}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022c73'),
#  'geocode': {'latitude': 51.078033, 'longitude': 1.17535}}
# {'RatingValue': 4,
#  '_id': ObjectId('6444c50c4e68f4e55d022c74'),
#  'geocode': {'latitude': 51.078033, 'longitude': 1.17535}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022c75'),
#  'geocode': {'latitude': 51.078033, 'longitude': 1.17535}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022c76'),
#  'geocode': {'latitude': 51.078515, 'longitude': 1.175811}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022c77'),
#  'geocode': {'latitude': 51.09221, 'longitude': 1.189834}}
# {'RatingValue': 4,
#  '_id': ObjectId('6444c50c4e68f4e55d022c78'),
#  'geocode': {'latitude': 51.078033, 'longitude': 1.17535}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022c79'),
#  'geocode': {'latitude': 51.078515, 'longitude': 1.175811}}
# {'RatingValue': 4,
#  '_id': ObjectId('6444c50c4e68f4e55d022c7a'),
#  'geocode': {'latitude': 51.09221, 'longitude': 1.189833}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022c7b'),
#  'geocode': {'latitude': 51.078718, 'longitude': 1.176296}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022c7c'),
#  'geocode': {'latitude': 51.0787391662598, 'longitude': 1.17591404914856}}
# {'RatingValue': None,
#  '_id': ObjectId('6444c50c4e68f4e55d022c7d'),
#  'geocode': {'latitude': 51.087382, 'longitude': 1.184803}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022c7e'),
#  'geocode': {'latitude': 51.078718, 'longitude': 1.176296}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022c7f'),
#  'geocode': {'latitude': 51.0788531, 'longitude': 1.1762215}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022c80'),
#  'geocode': {'latitude': 51.07873, 'longitude': 1.17584}}
# {'RatingValue': 1,
#  '_id': ObjectId('6444c50c4e68f4e55d022c81'),
#  'geocode': {'latitude': 51.07873, 'longitude': 1.17584}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022c82'),
#  'geocode': {'latitude': 51.07873, 'longitude': 1.17584}}
# {'RatingValue': 3,
#  '_id': ObjectId('6444c50c4e68f4e55d022c83'),
#  'geocode': {'latitude': 51.07873, 'longitude': 1.17584}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022c84'),
#  'geocode': {'latitude': 51.0812644958496, 'longitude': 1.17841398715973}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022c85'),
#  'geocode': {'latitude': 51.076647, 'longitude': 1.172728}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022c86'),
#  'geocode': {'latitude': 51.076647, 'longitude': 1.172728}}
# {'RatingValue': 4,
#  '_id': ObjectId('6444c50c4e68f4e55d022c87'),
#  'geocode': {'latitude': 51.088115, 'longitude': 1.18431}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022c88'),
#  'geocode': {'latitude': 51.088115, 'longitude': 1.18431}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022c89'),
#  'geocode': {'latitude': 51.088115, 'longitude': 1.18431}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022c8a'),
#  'geocode': {'latitude': 51.088115, 'longitude': 1.18431}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022c8b'),
#  'geocode': {'latitude': 51.088115, 'longitude': 1.18431}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022c8c'),
#  'geocode': {'latitude': 51.0806630002457, 'longitude': 1.17725700019713}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022c8d'),
#  'geocode': {'latitude': 51.0881644, 'longitude': 1.1842719}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022c8e'),
#  'geocode': {'latitude': 51.088115, 'longitude': 1.18431}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022c8f'),
#  'geocode': {'latitude': 51.076413, 'longitude': 1.172055}}
# {'RatingValue': 4,
#  '_id': ObjectId('6444c50c4e68f4e55d022c90'),
#  'geocode': {'latitude': 51.079039, 'longitude': 1.174748}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022c91'),
#  'geocode': {'latitude': 51.080171, 'longitude': 1.175782}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022c92'),
#  'geocode': {'latitude': 51.080171, 'longitude': 1.175782}}
# {'RatingValue': None,
#  '_id': ObjectId('6444c50c4e68f4e55d022c93'),
#  'geocode': {'latitude': 51.076577, 'longitude': 1.17198}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022c94'),
#  'geocode': {'latitude': 51.088333, 'longitude': 1.183925}}
# {'RatingValue': None,
#  '_id': ObjectId('6444c50c4e68f4e55d022c95'),
#  'geocode': {'latitude': 51.076577, 'longitude': 1.17198}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022c96'),
#  'geocode': {'latitude': 51.077414, 'longitude': 1.172652}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022c97'),
#  'geocode': {'latitude': 51.07856, 'longitude': 1.1748}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022c98'),
#  'geocode': {'latitude': 51.077414, 'longitude': 1.172652}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022c99'),
#  'geocode': {'latitude': 51.077492, 'longitude': 1.173056}}
# {'RatingValue': 4,
#  '_id': ObjectId('6444c50c4e68f4e55d022c9a'),
#  'geocode': {'latitude': 51.090286, 'longitude': 1.185859}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022c9b'),
#  'geocode': {'latitude': 51.089337, 'longitude': 1.18468}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022c9c'),
#  'geocode': {'latitude': 51.0833323, 'longitude': 1.1784191}}
# {'RatingValue': 3,
#  '_id': ObjectId('6444c50c4e68f4e55d022c9d'),
#  'geocode': {'latitude': 51.091129, 'longitude': 1.186289}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022c9e'),
#  'geocode': {'latitude': 51.077702, 'longitude': 1.172314}}
# {'RatingValue': 4,
#  '_id': ObjectId('6444c50c4e68f4e55d022c9f'),
#  'geocode': {'latitude': 51.074167, 'longitude': 1.16866}}
# {'RatingValue': 4,
#  '_id': ObjectId('6444c50c4e68f4e55d022ca0'),
#  'geocode': {'latitude': 51.076647, 'longitude': 1.172728}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022ca1'),
#  'geocode': {'latitude': 51.078197, 'longitude': 1.172619}}
# {'RatingValue': 3,
#  '_id': ObjectId('6444c50c4e68f4e55d022ca2'),
#  'geocode': {'latitude': 51.078197, 'longitude': 1.172619}}
# {'RatingValue': 3,
#  '_id': ObjectId('6444c50c4e68f4e55d022ca3'),
#  'geocode': {'latitude': 51.078197, 'longitude': 1.172619}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022ca5'),
#  'geocode': {'latitude': 51.078197, 'longitude': 1.172619}}
# {'RatingValue': 4,
#  '_id': ObjectId('6444c50c4e68f4e55d022ca6'),
#  'geocode': {'latitude': 51.078197, 'longitude': 1.172619}}
# {'RatingValue': 4,
#  '_id': ObjectId('6444c50c4e68f4e55d022ca7'),
#  'geocode': {'latitude': 51.078197, 'longitude': 1.172619}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022ca8'),
#  'geocode': {'latitude': 51.078197, 'longitude': 1.172619}}
# {'RatingValue': None,
#  '_id': ObjectId('6444c50c4e68f4e55d022ca9'),
#  'geocode': {'latitude': 51.082871, 'longitude': 1.177367}}
# {'RatingValue': 3,
#  '_id': ObjectId('6444c50c4e68f4e55d022caa'),
#  'geocode': {'latitude': 51.078197, 'longitude': 1.172619}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022cab'),
#  'geocode': {'latitude': 51.079192, 'longitude': 1.173416}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022cac'),
#  'geocode': {'latitude': 51.078068, 'longitude': 1.172054}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022cad'),
#  'geocode': {'latitude': 51.082381, 'longitude': 1.176219}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022cae'),
#  'geocode': {'latitude': 51.078885, 'longitude': 1.172452}}
# {'RatingValue': 4,
#  '_id': ObjectId('6444c50c4e68f4e55d022caf'),
#  'geocode': {'latitude': 51.081154, 'longitude': 1.174678}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022cb0'),
#  'geocode': {'latitude': 51.07623, 'longitude': 1.169515}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022cb1'),
#  'geocode': {'latitude': 51.07623, 'longitude': 1.169515}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022cb2'),
#  'geocode': {'latitude': 51.075403, 'longitude': 1.168516}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022cb3'),
#  'geocode': {'latitude': 51.085001, 'longitude': 1.177755}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022cb4'),
#  'geocode': {'latitude': 51.085038, 'longitude': 1.177729}}
# {'RatingValue': 2,
#  '_id': ObjectId('6444c50c4e68f4e55d022cb5'),
#  'geocode': {'latitude': 51.088893, 'longitude': 1.181507}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022cb6'),
#  'geocode': {'latitude': 51.085038, 'longitude': 1.177729}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022cb7'),
#  'geocode': {'latitude': 51.081291, 'longitude': 1.173631}}
# {'RatingValue': 4,
#  '_id': ObjectId('6444c50c4e68f4e55d022cb8'),
#  'geocode': {'latitude': 51.08129, 'longitude': 1.17363}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022cb9'),
#  'geocode': {'latitude': 51.078874, 'longitude': 1.171552}}
# {'RatingValue': 4,
#  '_id': ObjectId('6444c50c4e68f4e55d022cba'),
#  'geocode': {'latitude': 51.081291, 'longitude': 1.173631}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022cbb'),
#  'geocode': {'latitude': 51.077243, 'longitude': 1.168984}}
# {'RatingValue': 4,
#  '_id': ObjectId('6444c50c4e68f4e55d022cbc'),
#  'geocode': {'latitude': 51.085038, 'longitude': 1.177729}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022cbd'),
#  'geocode': {'latitude': 51.0819, 'longitude': 1.17373}}
# {'RatingValue': 4,
#  '_id': ObjectId('6444c50c4e68f4e55d022cbe'),
#  'geocode': {'latitude': 51.086485, 'longitude': 1.178428}}
# {'RatingValue': 4,
#  '_id': ObjectId('6444c50c4e68f4e55d022cbf'),
#  'geocode': {'latitude': 51.088124, 'longitude': 1.179997}}
# {'RatingValue': 4,
#  '_id': ObjectId('6444c50c4e68f4e55d022cc0'),
#  'geocode': {'latitude': 51.087034, 'longitude': 1.178766}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022cc1'),
#  'geocode': {'latitude': 51.085872, 'longitude': 1.177515}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022cc3'),
#  'geocode': {'latitude': 51.080302, 'longitude': 1.171635}}
# {'RatingValue': 4,
#  '_id': ObjectId('6444c50c4e68f4e55d022cc4'),
#  'geocode': {'latitude': 51.085365, 'longitude': 1.176952}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022cc5'),
#  'geocode': {'latitude': 51.090168, 'longitude': 1.181609}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022cc7'),
#  'geocode': {'latitude': 51.077289, 'longitude': 1.168302}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022cc8'),
#  'geocode': {'latitude': 51.08885, 'longitude': 1.180133}}
# {'RatingValue': 2,
#  '_id': ObjectId('6444c50c4e68f4e55d022cc9'),
#  'geocode': {'latitude': 51.088806, 'longitude': 1.180073}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022cca'),
#  'geocode': {'latitude': 51.082331, 'longitude': 1.173059}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022ccb'),
#  'geocode': {'latitude': 51.082332, 'longitude': 1.17306}}
# {'RatingValue': 4,
#  '_id': ObjectId('6444c50c4e68f4e55d022ccc'),
#  'geocode': {'latitude': 51.087034, 'longitude': 1.178766}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022ccd'),
#  'geocode': {'latitude': 51.080533, 'longitude': 1.172065}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022cce'),
#  'geocode': {'latitude': 51.081795, 'longitude': 1.172295}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022ccf'),
#  'geocode': {'latitude': 51.090195, 'longitude': 1.18094}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022cd0'),
#  'geocode': {'latitude': 51.077737, 'longitude': 1.167704}}
# {'RatingValue': 4,
#  '_id': ObjectId('6444c50c4e68f4e55d022cd1'),
#  'geocode': {'latitude': 51.07555, 'longitude': 1.165413}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022cd2'),
#  'geocode': {'latitude': 51.088125, 'longitude': 1.179998}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022cd3'),
#  'geocode': {'latitude': 51.08186, 'longitude': 1.171556}}
# {'RatingValue': 4,
#  '_id': ObjectId('6444c50c4e68f4e55d022cd4'),
#  'geocode': {'latitude': 51.0769439, 'longitude': 1.1665238}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022cd5'),
#  'geocode': {'latitude': 51.085552, 'longitude': 1.175336}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022cd6'),
#  'geocode': {'latitude': 51.087034, 'longitude': 1.178766}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022cd7'),
#  'geocode': {'latitude': 51.085553, 'longitude': 1.175337}}
# {'RatingValue': None,
#  '_id': ObjectId('6444c50c4e68f4e55d022cd8'),
#  'geocode': {'latitude': 51.0932246, 'longitude': 1.1829433}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022cd9'),
#  'geocode': {'latitude': 51.0817527770996, 'longitude': 1.17090594768524}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022cda'),
#  'geocode': {'latitude': 51.082374, 'longitude': 1.171506}}
# {'RatingValue': None,
#  '_id': ObjectId('6444c50c4e68f4e55d022cdb'),
#  'geocode': {'latitude': 51.082374, 'longitude': 1.171506}}
# {'RatingValue': 1,
#  '_id': ObjectId('6444c50c4e68f4e55d022cdc'),
#  'geocode': {'latitude': 51.082374, 'longitude': 1.171506}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022cdf'),
#  'geocode': {'latitude': 51.0751419067383, 'longitude': 1.16350066661835}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022ce0'),
#  'geocode': {'latitude': 51.076949, 'longitude': 1.164581}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022ce1'),
#  'geocode': {'latitude': 51.08382, 'longitude': 1.171591}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022ce2'),
#  'geocode': {'latitude': 51.083812713623, 'longitude': 1.17163395881653}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022ce3'),
#  'geocode': {'latitude': 51.07507, 'longitude': 1.162196}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022ce4'),
#  'geocode': {'latitude': 51.095177, 'longitude': 1.182639}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022ce5'),
#  'geocode': {'latitude': 51.095177, 'longitude': 1.182639}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022ce6'),
#  'geocode': {'latitude': 51.095177, 'longitude': 1.182639}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022ce7'),
#  'geocode': {'latitude': 51.095177, 'longitude': 1.182639}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022ce8'),
#  'geocode': {'latitude': 51.085755, 'longitude': 1.172865}}
# {'RatingValue': 4,
#  '_id': ObjectId('6444c50c4e68f4e55d022ce9'),
#  'geocode': {'latitude': 51.078911, 'longitude': 1.165543}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022cee'),
#  'geocode': {'latitude': 51.087373, 'longitude': 1.171919}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022cef'),
#  'geocode': {'latitude': 51.080017, 'longitude': 1.164533}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022cf1'),
#  'geocode': {'latitude': 51.087373, 'longitude': 1.171919}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022cf2'),
#  'geocode': {'latitude': 51.079404, 'longitude': 1.16362}}
# {'RatingValue': None,
#  '_id': ObjectId('6444c50c4e68f4e55d022cf4'),
#  'geocode': {'latitude': 51.076559, 'longitude': 1.160028}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022cf6'),
#  'geocode': {'latitude': 51.082434, 'longitude': 1.165969}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022cfb'),
#  'geocode': {'latitude': 51.081358, 'longitude': 1.164182}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022cfd'),
#  'geocode': {'latitude': 51.084325, 'longitude': 1.166898}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022cfe'),
#  'geocode': {'latitude': 51.084325, 'longitude': 1.166898}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022cff'),
#  'geocode': {'latitude': 51.090416, 'longitude': 1.173128}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022d00'),
#  'geocode': {'latitude': 51.3344841003418, 'longitude': 1.42664802074432}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022d01'),
#  'geocode': {'latitude': 51.090416, 'longitude': 1.173128}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022d02'),
#  'geocode': {'latitude': 51.0813407897949, 'longitude': 1.16422498226166}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022d03'),
#  'geocode': {'latitude': 51.335713, 'longitude': 1.427746}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022d04'),
#  'geocode': {'latitude': 51.335713, 'longitude': 1.427746}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022d05'),
#  'geocode': {'latitude': 51.336816, 'longitude': 1.428762}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022d06'),
#  'geocode': {'latitude': 51.085871, 'longitude': 1.167918}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022d07'),
#  'geocode': {'latitude': 51.076715, 'longitude': 1.158282}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022d08'),
#  'geocode': {'latitude': 51.338414, 'longitude': 1.429786}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022d09'),
#  'geocode': {'latitude': 51.338414, 'longitude': 1.429786}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022d0b'),
#  'geocode': {'latitude': 51.3322105407715, 'longitude': 1.42320394515991}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022d0c'),
#  'geocode': {'latitude': 51.082833, 'longitude': 1.168524}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022d0d'),
#  'geocode': {'latitude': 51.08538, 'longitude': 1.171755}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022d0e'),
#  'geocode': {'latitude': 51.085565, 'longitude': 1.168597}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022d0f'),
#  'geocode': {'latitude': 51.33222, 'longitude': 1.423192}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022d10'),
#  'geocode': {'latitude': 51.33222, 'longitude': 1.423192}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022d11'),
#  'geocode': {'latitude': 51.332221, 'longitude': 1.423192}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022d12'),
#  'geocode': {'latitude': 51.332221, 'longitude': 1.423192}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022d13'),
#  'geocode': {'latitude': 51.332221, 'longitude': 1.423192}}
# {'RatingValue': 4,
#  '_id': ObjectId('6444c50c4e68f4e55d022d14'),
#  'geocode': {'latitude': 51.332221, 'longitude': 1.423192}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022d15'),
#  'geocode': {'latitude': 51.33222, 'longitude': 1.423192}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022d16'),
#  'geocode': {'latitude': 51.332221, 'longitude': 1.423192}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022d17'),
#  'geocode': {'latitude': 51.332221, 'longitude': 1.423192}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022d18'),
#  'geocode': {'latitude': 51.332221, 'longitude': 1.423192}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022d19'),
#  'geocode': {'latitude': 51.332221, 'longitude': 1.423192}}
# {'RatingValue': 4,
#  '_id': ObjectId('6444c50c4e68f4e55d022d1a'),
#  'geocode': {'latitude': 51.3322219848633, 'longitude': 1.42319202423096}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022d1b'),
#  'geocode': {'latitude': 51.092175, 'longitude': 1.173634}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022d1d'),
#  'geocode': {'latitude': 51.3351135253906, 'longitude': 1.42612195014954}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022d1e'),
#  'geocode': {'latitude': 51.087041, 'longitude': 1.168241}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022d1f'),
#  'geocode': {'latitude': 51.331022, 'longitude': 1.421136}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022d20'),
#  'geocode': {'latitude': 51.349914, 'longitude': 1.440672}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022d22'),
#  'geocode': {'latitude': 51.332386, 'longitude': 1.421525}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022d23'),
#  'geocode': {'latitude': 51.332221, 'longitude': 1.423192}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022d24'),
#  'geocode': {'latitude': 51.332386, 'longitude': 1.421525}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022d25'),
#  'geocode': {'latitude': 51.332386, 'longitude': 1.421525}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022d26'),
#  'geocode': {'latitude': 51.332221, 'longitude': 1.423192}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50c4e68f4e55d022d27'),
# ...
# {'RatingValue': None,
#  '_id': ObjectId('6444c50d4e68f4e55d027916'),
#  'geocode': {'latitude': 51.2709274291992, 'longitude': 0.191339999437332}}
# {'RatingValue': None,
#  '_id': ObjectId('6444c50d4e68f4e55d027917'),
#  'geocode': {'latitude': 51.270929, 'longitude': 0.19134}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50d4e68f4e55d027918'),
#  'geocode': {'latitude': 51.2720394, 'longitude': 0.1924353}}
# {'RatingValue': None,
#  '_id': ObjectId('6444c50d4e68f4e55d027919'),
#  'geocode': {'latitude': 51.608959197998, 'longitude': 0.53379899263382}}
# {'RatingValue': 4,
#  '_id': ObjectId('6444c50d4e68f4e55d02791a'),
#  'geocode': {'latitude': 51.611988, 'longitude': 0.536887}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50d4e68f4e55d02791b'),
#  'geocode': {'latitude': 51.611988, 'longitude': 0.536887}}
# {'RatingValue': None,
#  '_id': ObjectId('6444c50d4e68f4e55d02791c'),
#  'geocode': {'latitude': 51.5574975, 'longitude': 0.4810754}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50d4e68f4e55d02791d'),
#  'geocode': {'latitude': 51.557786, 'longitude': 0.481367}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50d4e68f4e55d02791e'),
#  'geocode': {'latitude': 51.524999, 'longitude': 0.447866}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50d4e68f4e55d02791f'),
#  'geocode': {'latitude': 51.436189, 'longitude': 0.357558}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50d4e68f4e55d027920'),
#  'geocode': {'latitude': 51.5259444, 'longitude': 0.4487384}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50d4e68f4e55d027921'),
#  'geocode': {'latitude': 51.445348, 'longitude': 0.366737}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50d4e68f4e55d027922'),
#  'geocode': {'latitude': 51.272743, 'longitude': 0.192874}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50d4e68f4e55d027923'),
#  'geocode': {'latitude': 51.265469, 'longitude': 0.1855}}
# {'RatingValue': None,
#  '_id': ObjectId('6444c50d4e68f4e55d027924'),
#  'geocode': {'latitude': 51.868531, 'longitude': 0.80248}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50d4e68f4e55d027925'),
#  'geocode': {'latitude': 51.271898, 'longitude': 0.191916}}
# {'RatingValue': 4,
#  '_id': ObjectId('6444c50d4e68f4e55d027926'),
#  'geocode': {'latitude': 51.52503, 'longitude': 0.44768}}
# {'RatingValue': 3,
#  '_id': ObjectId('6444c50d4e68f4e55d027927'),
#  'geocode': {'latitude': 51.525029, 'longitude': 0.44768}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50d4e68f4e55d027928'),
#  'geocode': {'latitude': 51.524264, 'longitude': 0.44689}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50d4e68f4e55d027929'),
#  'geocode': {'latitude': 51.568013, 'longitude': 0.491491}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50d4e68f4e55d02792a'),
#  'geocode': {'latitude': 51.287956237793, 'longitude': 0.207911998033524}}
# {'RatingValue': 4,
#  '_id': ObjectId('6444c50d4e68f4e55d02792b'),
#  'geocode': {'latitude': 51.271476, 'longitude': 0.191394}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50d4e68f4e55d02792c'),
#  'geocode': {'latitude': 51.272553, 'longitude': 0.192478}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50d4e68f4e55d02792d'),
#  'geocode': {'latitude': 51.438909, 'longitude': 0.360044}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50d4e68f4e55d02792e'),
#  'geocode': {'latitude': 51.273091, 'longitude': 0.19299}}
# {'RatingValue': 4,
#  '_id': ObjectId('6444c50d4e68f4e55d02792f'),
#  'geocode': {'latitude': 51.277027130127, 'longitude': 0.196903005242348}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50d4e68f4e55d027930'),
#  'geocode': {'latitude': 51.569845, 'longitude': 0.493294}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50d4e68f4e55d027931'),
#  'geocode': {'latitude': 51.273092, 'longitude': 0.192991}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50d4e68f4e55d027932'),
#  'geocode': {'latitude': 51.277039, 'longitude': 0.196863}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50d4e68f4e55d027933'),
#  'geocode': {'latitude': 51.2726769, 'longitude': 0.1924943}}
# {'RatingValue': 3,
#  '_id': ObjectId('6444c50d4e68f4e55d027934'),
#  'geocode': {'latitude': 51.277039, 'longitude': 0.196863}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50d4e68f4e55d027935'),
#  'geocode': {'latitude': 51.277039, 'longitude': 0.196863}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50d4e68f4e55d027936'),
#  'geocode': {'latitude': 51.804567, 'longitude': 0.735404}}
# {'RatingValue': None,
#  '_id': ObjectId('6444c50d4e68f4e55d027937'),
#  'geocode': {'latitude': 51.2723334, 'longitude': 0.1921052}}
# {'RatingValue': 4,
#  '_id': ObjectId('6444c50d4e68f4e55d027938'),
#  'geocode': {'latitude': 51.557286, 'longitude': 0.48033}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50d4e68f4e55d027939'),
#  'geocode': {'latitude': 51.272459, 'longitude': 0.192186}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50d4e68f4e55d02793a'),
#  'geocode': {'latitude': 51.27246, 'longitude': 0.192187}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50d4e68f4e55d02793b'),
#  'geocode': {'latitude': 51.4412612915039, 'longitude': 0.362035989761353}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50d4e68f4e55d02793c'),
#  'geocode': {'latitude': 51.611988, 'longitude': 0.536887}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50d4e68f4e55d02793d'),
#  'geocode': {'latitude': 51.602557, 'longitude': 0.526338}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50d4e68f4e55d02793e'),
#  'geocode': {'latitude': 51.441261, 'longitude': 0.362036}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50d4e68f4e55d02793f'),
#  'geocode': {'latitude': 51.5249900817871, 'longitude': 0.446972012519836}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50d4e68f4e55d027940'),
#  'geocode': {'latitude': 51.524991, 'longitude': 0.446972}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50d4e68f4e55d027941'),
#  'geocode': {'latitude': 51.273079, 'longitude': 0.1923874}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50d4e68f4e55d027942'),
#  'geocode': {'latitude': 51.5247268676758, 'longitude': 0.446655005216599}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50d4e68f4e55d027943'),
#  'geocode': {'latitude': 51.273082, 'longitude': 0.1924706}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50d4e68f4e55d027944'),
#  'geocode': {'latitude': 51.524728, 'longitude': 0.446655}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50d4e68f4e55d027945'),
#  'geocode': {'latitude': 51.939121, 'longitude': 0.875529}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50d4e68f4e55d027946'),
#  'geocode': {'latitude': 51.705039, 'longitude': 0.631642}}
# {'RatingValue': 4,
#  '_id': ObjectId('6444c50d4e68f4e55d027947'),
#  'geocode': {'latitude': 51.524728, 'longitude': 0.446655}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50d4e68f4e55d027948'),
#  'geocode': {'latitude': 51.4347219, 'longitude': 0.3551191}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50d4e68f4e55d027949'),
#  'geocode': {'latitude': 51.523761, 'longitude': 0.445579}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50d4e68f4e55d02794a'),
#  'geocode': {'latitude': 51.27337, 'longitude': 0.192574}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50d4e68f4e55d02794b'),
#  'geocode': {'latitude': 51.526333, 'longitude': 0.448168}}
# {'RatingValue': 4,
#  '_id': ObjectId('6444c50d4e68f4e55d02794c'),
#  'geocode': {'latitude': 51.524319, 'longitude': 0.445999}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50d4e68f4e55d02794d'),
#  'geocode': {'latitude': 51.383404, 'longitude': 0.303047}}
# {'RatingValue': 4,
#  '_id': ObjectId('6444c50d4e68f4e55d02794e'),
#  'geocode': {'latitude': 51.383404, 'longitude': 0.303047}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50d4e68f4e55d02794f'),
#  'geocode': {'latitude': 51.4305761, 'longitude': 0.3507339}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50d4e68f4e55d027950'),
#  'geocode': {'latitude': 51.3834037780762, 'longitude': 0.303047001361847}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50d4e68f4e55d027951'),
#  'geocode': {'latitude': 51.2713017382881, 'longitude': 0.190144487495874}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50d4e68f4e55d027952'),
#  'geocode': {'latitude': 51.281418, 'longitude': 0.200271}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50d4e68f4e55d027953'),
#  'geocode': {'latitude': 51.278991, 'longitude': 0.197832}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50d4e68f4e55d027954'),
#  'geocode': {'latitude': 51.384194, 'longitude': 0.303532}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50d4e68f4e55d027955'),
#  'geocode': {'latitude': 51.442202, 'longitude': 0.362199}}
# {'RatingValue': 4,
#  '_id': ObjectId('6444c50d4e68f4e55d027956'),
#  'geocode': {'latitude': 51.4891815185547, 'longitude': 0.409887999296188}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50d4e68f4e55d027957'),
#  'geocode': {'latitude': 51.434183, 'longitude': 0.354001}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50d4e68f4e55d027958'),
#  'geocode': {'latitude': 51.434183, 'longitude': 0.354001}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50d4e68f4e55d027959'),
#  'geocode': {'latitude': 51.27504, 'longitude': 0.193642}}
# {'RatingValue': 4,
#  '_id': ObjectId('6444c50d4e68f4e55d02795a'),
#  'geocode': {'latitude': 51.939646, 'longitude': 0.875388}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50d4e68f4e55d02795b'),
#  'geocode': {'latitude': 51.438909, 'longitude': 0.360044}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50d4e68f4e55d02795c'),
#  'geocode': {'latitude': 51.611988, 'longitude': 0.536886}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50d4e68f4e55d02795d'),
#  'geocode': {'latitude': 51.611988, 'longitude': 0.536887}}
# {'RatingValue': 4,
#  '_id': ObjectId('6444c50d4e68f4e55d02795e'),
#  'geocode': {'latitude': 51.283851, 'longitude': 0.202897}}
# {'RatingValue': 4,
#  '_id': ObjectId('6444c50d4e68f4e55d02795f'),
#  'geocode': {'latitude': 51.614937, 'longitude': 0.538193}}
# {'RatingValue': 4,
#  '_id': ObjectId('6444c50d4e68f4e55d027960'),
#  'geocode': {'latitude': 51.43482, 'longitude': 0.354494}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50d4e68f4e55d027961'),
#  'geocode': {'latitude': 51.4340099, 'longitude': 0.3533205}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50d4e68f4e55d027962'),
#  'geocode': {'latitude': 51.63529, 'longitude': 0.55868}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50d4e68f4e55d027963'),
#  'geocode': {'latitude': 51.387555, 'longitude': 0.306417}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50d4e68f4e55d027964'),
#  'geocode': {'latitude': 51.4343666, 'longitude': 0.3536633}}
# {'RatingValue': 4,
#  '_id': ObjectId('6444c50d4e68f4e55d027965'),
#  'geocode': {'latitude': 51.2721261, 'longitude': 0.1902029}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50d4e68f4e55d027966'),
#  'geocode': {'latitude': 51.433959, 'longitude': 0.353083}}
# {'RatingValue': 4,
#  '_id': ObjectId('6444c50d4e68f4e55d027967'),
#  'geocode': {'latitude': 51.433959, 'longitude': 0.353083}}
# {'RatingValue': 4,
#  '_id': ObjectId('6444c50d4e68f4e55d027968'),
#  'geocode': {'latitude': 51.433959, 'longitude': 0.353083}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50d4e68f4e55d027969'),
#  'geocode': {'latitude': 51.433959, 'longitude': 0.353083}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50d4e68f4e55d02796a'),
#  'geocode': {'latitude': 51.26347, 'longitude': 0.181424}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50d4e68f4e55d02796b'),
#  'geocode': {'latitude': 51.433959, 'longitude': 0.353083}}
# {'RatingValue': 4,
#  '_id': ObjectId('6444c50d4e68f4e55d02796c'),
#  'geocode': {'latitude': 51.564348, 'longitude': 0.48575}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50d4e68f4e55d02796d'),
#  'geocode': {'latitude': 51.43589, 'longitude': 0.355413}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50d4e68f4e55d02796e'),
#  'geocode': {'latitude': 51.43589, 'longitude': 0.355413}}
# {'RatingValue': 4,
#  '_id': ObjectId('6444c50d4e68f4e55d02796f'),
#  'geocode': {'latitude': 51.434821, 'longitude': 0.354495}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50d4e68f4e55d027970'),
#  'geocode': {'latitude': 51.272442, 'longitude': 0.190709}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50d4e68f4e55d027971'),
#  'geocode': {'latitude': 51.385463, 'longitude': 0.303955}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50d4e68f4e55d027972'),
#  'geocode': {'latitude': 51.3854522705078, 'longitude': 0.303966999053955}}
# {'RatingValue': None,
#  '_id': ObjectId('6444c50d4e68f4e55d027973'),
#  'geocode': {'latitude': 51.270734, 'longitude': 0.188233}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50d4e68f4e55d027974'),
#  'geocode': {'latitude': 51.272483, 'longitude': 0.189951}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50d4e68f4e55d027975'),
#  'geocode': {'latitude': 51.313247, 'longitude': 0.230608}}
# {'RatingValue': 3,
#  '_id': ObjectId('6444c50d4e68f4e55d027976'),
#  'geocode': {'latitude': 51.489795, 'longitude': 0.408956}}
# {'RatingValue': 3,
#  '_id': ObjectId('6444c50d4e68f4e55d027977'),
#  'geocode': {'latitude': 51.489796, 'longitude': 0.408957}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50d4e68f4e55d027978'),
#  'geocode': {'latitude': 51.3910675048828, 'longitude': 0.308865010738373}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50d4e68f4e55d027979'),
#  'geocode': {'latitude': 51.776068, 'longitude': 0.703074}}
# {'RatingValue': 4,
#  '_id': ObjectId('6444c50d4e68f4e55d02797a'),
#  'geocode': {'latitude': 51.437837, 'longitude': 0.356118}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50d4e68f4e55d02797b'),
#  'geocode': {'latitude': 51.819556, 'longitude': 0.74824}}
# {'RatingValue': None,
#  '_id': ObjectId('6444c50d4e68f4e55d02797c'),
#  'geocode': {'latitude': 51.914788, 'longitude': 0.848014}}
# {'RatingValue': 1,
#  '_id': ObjectId('6444c50d4e68f4e55d02797d'),
#  'geocode': {'latitude': 51.489796, 'longitude': 0.408957}}
# {'RatingValue': 4,
#  '_id': ObjectId('6444c50d4e68f4e55d02797e'),
#  'geocode': {'latitude': 51.434074, 'longitude': 0.352255}}
# {'RatingValue': None,
#  '_id': ObjectId('6444c50d4e68f4e55d02797f'),
#  'geocode': {'latitude': 51.912733, 'longitude': 0.845616}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50d4e68f4e55d027980'),
#  'geocode': {'latitude': 51.434074, 'longitude': 0.352255}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50d4e68f4e55d027981'),
#  'geocode': {'latitude': 51.434074, 'longitude': 0.352255}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50d4e68f4e55d027982'),
#  'geocode': {'latitude': 51.434074, 'longitude': 0.352255}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50d4e68f4e55d027983'),
#  'geocode': {'latitude': 51.434074, 'longitude': 0.352255}}
# {'RatingValue': 4,
#  '_id': ObjectId('6444c50d4e68f4e55d027984'),
#  'geocode': {'latitude': 51.434074, 'longitude': 0.352255}}
# {'RatingValue': 4,
#  '_id': ObjectId('6444c50d4e68f4e55d027985'),
#  'geocode': {'latitude': 51.434074, 'longitude': 0.352255}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50d4e68f4e55d027986'),
#  'geocode': {'latitude': 51.2723902, 'longitude': 0.1900291}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50d4e68f4e55d027987'),
#  'geocode': {'latitude': 51.9147758483887, 'longitude': 0.848026990890503}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50d4e68f4e55d027988'),
#  'geocode': {'latitude': 51.2707366943359, 'longitude': 0.188234001398087}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50d4e68f4e55d027989'),
#  'geocode': {'latitude': 51.2619158000354, 'longitude': 0.178903150321647}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50d4e68f4e55d02798a'),
#  'geocode': {'latitude': 51.565311, 'longitude': 0.48573}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50d4e68f4e55d02798b'),
#  'geocode': {'latitude': 51.672011, 'longitude': 0.595203}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50d4e68f4e55d02798c'),
#  'geocode': {'latitude': 51.614151, 'longitude': 0.535462}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50d4e68f4e55d02798d'),
#  'geocode': {'latitude': 51.272219, 'longitude': 0.188706}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50d4e68f4e55d02798e'),
#  'geocode': {'latitude': 51.343505859375, 'longitude': 0.26018899679184}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50d4e68f4e55d02798f'),
#  'geocode': {'latitude': 51.95426, 'longitude': 0.888623}}
# {'RatingValue': 5,
#  '_id': ObjectId('6444c50d4e68f4e55d027990'),
#  'geocode': {'latitude': 51.3830962, 'longitude': 0.3003126}}
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
